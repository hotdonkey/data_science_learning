# %%
import numpy as np
import pandas as pd
df = pd.read_excel('data/тест вагоны.xlsx', skiprows=8)

# %%
df.head()
# Out:
#                  Дата                                           Документ  \
# 0  07.09.2022 2:00:00  Поступление (акт, накладная, УПД) 00BE-088207 ...
# 1  07.09.2022 2:00:00  Поступление (акт, накладная, УПД) 00BE-088207 ...
# 2  14.09.2022 2:00:00  Поступление (акт, накладная, УПД) 00BE-088775 ...
# 3  14.09.2022 2:00:00  Поступление (акт, накладная, УПД) 00BE-088775 ...
# 4  19.09.2022 2:00:00  Поступление (акт, накладная, УПД) 00BE-089149 ...
#
#                         Подразделение Дт  \
# 0                      Цех_Шелехов ОП №2
# 1  Производственная служба_Керамкомбинат
# 2                      Цех_Шелехов ОП №2
# 3  Производственная служба_Керамкомбинат
# 4                      Цех_Шелехов ОП №2
#
#                                         Субконто1 Дт Субконто1 Кт  \
# 0  25.05.11.2. Доставка сырья и материалов железн...      РЖД ОАО
# 1  25.05.11.2. Доставка сырья и материалов железн...      РЖД ОАО
# 2  25.05.11.2. Доставка сырья и материалов железн...      РЖД ОАО
# 3  25.05.11.2. Доставка сырья и материалов железн...      РЖД ОАО
# 4  25.05.11.2. Доставка сырья и материалов железн...      РЖД ОАО
#
#                                           Содержание  Счет Дт    Сумма  \
# 0  Транспортные услуги по перевозке грузов код ст...       25   100000
# 1  Транспортные услуги по перевозке грузов код ст...       25   200000
# 2  Транспортные услуги по перевозке грузов код ст...       25  1300000
# 3  Транспортные услуги по перевозке грузов код ст...       25  1400000
# 4  Транспортные услуги по перевозке грузов код ст...       25  2200000
#
#                   Unnamed: 8
# 0                        СТК
# 1                        СТК
# 2                        СТК
# 3                        СТК
# 4  СТК + КМП последний вагон

# %%
def car_number_sep(data):
    data = data.replace('ст. ', 'ст.').split(sep=' ')
    new_data = []
    for i in data:
        i = i.replace(',' , '')
        try:
            if len(i)>4:
                i = int(i)
                new_data.append(i)
        except ValueError:
            pass
    return new_data

df['Номер вагона'] = df['Содержание'].apply(car_number_sep)
df = df.explode(column='Номер вагона')

# %%
df.to_excel('data/разбивка по вагонам.xlsx')

# %%
df.head()
# Out:
#                  Дата                                           Документ  \
# 0  07.09.2022 2:00:00  Поступление (акт, накладная, УПД) 00BE-088207 ...
# 0  07.09.2022 2:00:00  Поступление (акт, накладная, УПД) 00BE-088207 ...
# 0  07.09.2022 2:00:00  Поступление (акт, накладная, УПД) 00BE-088207 ...
# 0  07.09.2022 2:00:00  Поступление (акт, накладная, УПД) 00BE-088207 ...
# 0  07.09.2022 2:00:00  Поступление (акт, накладная, УПД) 00BE-088207 ...
#
#     Подразделение Дт                                       Субконто1 Дт  \
# 0  Цех_Шелехов ОП №2  25.05.11.2. Доставка сырья и материалов железн...
# 0  Цех_Шелехов ОП №2  25.05.11.2. Доставка сырья и материалов железн...
# 0  Цех_Шелехов ОП №2  25.05.11.2. Доставка сырья и материалов железн...
# 0  Цех_Шелехов ОП №2  25.05.11.2. Доставка сырья и материалов железн...
# 0  Цех_Шелехов ОП №2  25.05.11.2. Доставка сырья и материалов железн...
#
#   Субконто1 Кт                                         Содержание  Счет Дт  \
# 0      РЖД ОАО  Транспортные услуги по перевозке грузов код ст...       25
# 0      РЖД ОАО  Транспортные услуги по перевозке грузов код ст...       25
# 0      РЖД ОАО  Транспортные услуги по перевозке грузов код ст...       25
# 0      РЖД ОАО  Транспортные услуги по перевозке грузов код ст...       25
# 0      РЖД ОАО  Транспортные услуги по перевозке грузов код ст...       25
#
#     Сумма Unnamed: 8 Номер вагона
# 0  100000        СТК     98467244
# 0  100000        СТК     98462799
# 0  100000        СТК     60591260
# 0  100000        СТК     62175682
# 0  100000        СТК     65397853
