# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import pprint
import lxml
import xml.etree.ElementTree as ET

URL = 'http://www.cbr.ru/scripts/XML_dynamic.asp?date_req1=01/10/2022&date_req2=31/12/2022&VAL_NM_RQ=R01235 '

headers = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'
}



dict_of_currencies = {
    'R01235':'USD',
    'R01239':'EUR',
    'R01010':'Australian Dollar',
    'R01375':'China Yuan',
    'R01035':'British Pound',
    'R01335':'Kazakhstan Tenge',
    'R01815':'Japanese Yen',
    'R01775':'Swiss Franc'
}

list_of_currencies = [dict_of_currencies.keys()]

response = requests.get(URL, headers=headers)

# %%
#url_link = requests.get(URL)
#file = BeautifulSoup(url_link.text, "xml")

# %%
#content = file.find

# %%
usd_df = pd.read_xml(URL) #in our case we've got a decent table that we can use
usd_df['Date'] = pd.to_datetime(usd_df['Date'], dayfirst=True)
usd_df['Value'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 3
#       1 usd_df = pd.read_xml(URL) #in our case we've got a decent table that we can use
#       2 usd_df['Date'] = pd.to_datetime(usd_df['Date'], dayfirst=True)
# ----> 3 usd_df['Value'].astype('int')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
usd_df
# Out:
#          Date      Id  Nominal    Value
# 0  2022-10-01  R01235        1  55,2987
# 1  2022-10-04  R01235        1  57,5664
# 2  2022-10-05  R01235        1  58,7913
# 3  2022-10-06  R01235        1  59,4043
# 4  2022-10-07  R01235        1  60,2534
# 5  2022-10-08  R01235        1  61,2475
# 6  2022-10-11  R01235        1  62,3126
# 7  2022-10-12  R01235        1  63,6840
# 8  2022-10-13  R01235        1  63,7559
# 9  2022-10-14  R01235        1  63,4917
# 10 2022-10-15  R01235        1  63,0558
# 11 2022-10-18  R01235        1  61,7634
# 12 2022-10-19  R01235        1  61,7032
# 13 2022-10-20  R01235        1  61,5905
# 14 2022-10-21  R01235        1  61,5018
# 15 2022-10-22  R01235        1  61,1958
# 16 2022-10-25  R01235        1  61,1629
# 17 2022-10-26  R01235        1  61,3326
# 18 2022-10-27  R01235        1  61,4277
# 19 2022-10-28  R01235        1  61,3589
# 20 2022-10-29  R01235        1  61,5343
# 21 2022-11-01  R01235        1  61,6229
# ...

# %%
usd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     60 non-null     datetime64[ns]
#  1   Id       60 non-null     object
#  2   Nominal  60 non-null     int64
#  3   Value    60 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 2.0+ KB
